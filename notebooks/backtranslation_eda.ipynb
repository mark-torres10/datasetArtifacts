# %% [markdown]
# # EDA on Backtranslated Samples
#
# Now that we have backtranslated samples for both Spanish and Japanese, this
# notebook will analyze those samples as well as the original English samples.

# %%
import ast
import os
from typing import List

import pandas as pd
import spacy

# %%
#!python -m spacy download en_core_web_sm
nlp = spacy.load('en_core_web_sm')

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Load data

# %%
ROOT_DIR = "../data/consolidated"

SPANISH_BACKTRANSLATIONS = "spanish_consolidated_backtranslations.jsonl"
SPANISH_DATA_FP = os.path.join(ROOT_DIR, SPANISH_BACKTRANSLATIONS)

JAPANESE_BACKTRANSLATIONS = "japanese_consolidated_backtranslations.jsonl"
JAPANESE_DATA_FP = os.path.join(ROOT_DIR, JAPANESE_BACKTRANSLATIONS)

# %%
spanish_consolidated_data = []

# %%
with open(SPANISH_DATA_FP, 'r') as f:
    for line in f.readlines():
        spanish_consolidated_data.append(
            ast.literal_eval(line)
        )

# %%
japanese_consolidated_data = []

# %%
with open(JAPANESE_DATA_FP, 'r') as f:
    for line in f.readlines():
        japanese_consolidated_data.append(
            ast.literal_eval(line)
        )

# %%
consolidated_backtranslated_data = (
    spanish_consolidated_data + japanese_consolidated_data
)

# %%
df = pd.DataFrame(consolidated_backtranslated_data)

# %% [markdown]
# ### How many of the backtranslations are exactly the same as the originals?

# %%
df["pivot_lang"].value_counts()
# Out:
# es    1000
# ja    1000
# Name: pivot_lang, dtype: int64

# %%
df.groupby("pivot_lang").apply(
    lambda x: pd.Series(
        {
            "identical": (x.question == x.backtranslation).sum()
        }
    )
)
# Out:
#             identical
# pivot_lang
# es                200
# ja                 61

# %% [markdown]
# ### How many backtranslations had their entities changed?

# %%
def get_text_entities(text: str):
    doc = nlp(text)
    return {str(ent) for ent in doc.ents}

# %%
def get_text_entities_for_series(col: pd.Series):
    return [
        get_text_entities(str(elem)) for elem in col
    ]

# %%
ents_identical = [
    get_text_entities(question) == get_text_entities(backtranslation)
    for (question, backtranslation)
    in zip(df["question"], df["backtranslation"])
]

# %%
ents_identical_by_lang = pd.DataFrame(
    zip(ents_identical, df["pivot_lang"], df["question"], df["backtranslation"]),
    columns=["ents_identical", "pivot_lang", "question", "backtranslation"]
)

# %%
ents_identical_by_lang[["ents_identical", "pivot_lang"]].groupby("pivot_lang").sum()
# Out:
#             ents_identical
# pivot_lang
# es                     785
# ja                     705

# %%
ents_identical_by_lang[~ents_identical_by_lang["ents_identical"]].head(30)
# Out:
#      ents_identical pivot_lang  \
# 13            False         es
# 24            False         es
# 27            False         es
# 28            False         es
# 29            False         es
# 53            False         es
# 55            False         es
# 70            False         es
# 75            False         es
# 79            False         es
# 81            False         es
# 84            False         es
# 86            False         es
# 87            False         es
# 103           False         es
# 104           False         es
# 105           False         es
# 129           False         es
# 131           False         es
# 135           False         es
# 137           False         es
# 138           False         es
# 147           False         es
# 152           False         es
# 154           False         es
# 163           False         es
# 164           False         es
# 166           False         es
# 167           False         es
# 169           False         es
#
#                                                                                                                                                                 question  \
# 13                                                                                                         The Kingdom of the Netherlands was formed by which countries?
# 24                                                                                                                                       What Treaty is the CAF part of?
# 27                                                                                                                            What is an example of a Sassanid language?
# 28                                                                                                           At what century's start did revivalist fall into disfavor?
# 29                                                                                                                What is one type of fixture commonly found in offices?
# 53                                                                                                                             Each Brigade contains how many regiments?
# 55                                                  What characteristic of Middle Iranian civilization is shown by the number of different languages and their speakers?
# 70                                                                                                                    Who was the author of Seven Lamps of Architecture?
# 75                                                                                                                                 Who advises the Chief of the Defence?
# 79                                                                                                              Where is the current focus of the Canadian Military set?
# 81   What is an example of a condition that must be met for the Internet Archive data to be considered acceptable for submission to patent offices in the US and Europe?
# 84                                                                                                         The Dutch Republic was a republic of Europe during what time?
# 86                                                                                                    What famous World War II battle was the Canadian Military part of?
# 87                                                                                                                             In 1939, how many Cardinals were Italian?
# 103                                                                                                                      What century was the architect Le Corbusier in?
# 104                                                                                      What other title does the Dean of Collge of Cardinals receive upon appointment?
# 105                                                                                                                       How were the Canadian Forces upgraded in 2008?
# 129                                                                                                            What are some other names the Dutch Republic is known by?
# 131                                                                                                          What effort was the Canadian Military known for in Germany?
# 135                                                                                            The Canadian Armed Forces were initially organized under what department?
# 137                                                                                             Which branches of the national military does the U.S. president command?
# 138                                                                                                  Which government was responsible in Canadian history for this fact?
# 147                                                                                            Who did Healthcare advocates change their case to include as a defendant?
# 152                                                                                                 What prevented Canada from fully having their own army at the start?
# 154                                                                               Would you want to use passive infrared sensor in a area requiring 360-degree coverage?
# 163                                                         In which Federalist paper did James Madison state that the legislative branch of government was predominate?
# 164                                                                                                       The Low Countries were made up of which present day countries?
# 166                                                                                            In what type of relationship does an organism travel by means of another?
# 167                                                                                                    In what jurisdiction were Internet Archive's counterclaims filed?
# 169                                                                                                                        What is the task of the CAF Cyber Task Force?
#
#                                                                                                                                                 backtranslation
# 13                                                                                                       What countries made up the Kingdom of the Netherlands?
# 24                                                                                                                                  What Treaty is CAF part of?
# 27                                                                                                                   What is an example of a Sasanian language?
# 28                                                                                          At the beginning of what century did the revival fall out of favor?
# 29                                                                                                       What is a type of accessory commonly found in offices?
# 53                                                                                                                How many regiments does each Brigade contain?
# 55                                         Which characteristic of the average Iranian civilization shows the number of different languages and their speakers?
# 70                                                                                                              Who was the author of Seven Architecture Lamps?
# 75                                                                                                                            Who advises the Chief of Defense?
# 79                                                                                                Where is the current focus of the Canadian military ensemble?
# 81   What is an example of a condition that must be met for Internet Archive data to be considered acceptable for submission to US and European patent offices?
# 84                                                                                                During what time was the Dutch Republic a republic of Europe?
# 86                                                                                       In which famous World War II battle did the Canadian Army participate?
# 87                                                                                                                    In 1939, how many cardinals were Italian?
# 103                                                                                                             In what century was the architect Le Corbusier?
# 104                                                                    What other title does the Dean of the College of Cardinals receive upon being appointed?
# 105                                                                                                                How did the Canadian Forces improve in 2008?
# 129                                                                                                            By what other names is the Dutch Republic known?
# 131                                                                                                     What effort was the Canadian Army known for in Germany?
# 135                                                                                   Under which department was the Canadian Armed Forces initially organized?
# 137                                                                                       What branches of the national military does the US President command?
# 138                                                                                     What government was responsible in the history of Canada for this fact?
# 147                                                                            Who did the health care advocates change in your case to include as a defendant?
# 152                                                                                                    What prevented Canada from having its own army at first?
# 154                                                               Would you like to use a passive infrared sensor in an area that requires 360 degree coverage?
# 163                                               In which federalist newspaper did James Madison claim that the legislative branch of government predominated?
# 164                                                                                                      What modern countries were the Netherlands made up of?
# 166                                                                                      In what kind of relationship does one organism travel through another?
# 167                                                                                         In what jurisdiction were the Internet Archive counterclaims filed?
# 169                                                                                                                 What is the task of CAF's Cyber Task Force?

# %%
ents_identical_by_lang[ents_identical_by_lang["pivot_lang"] == "ja"][
    ~ents_identical_by_lang["ents_identical"]
].head(30)
# Out:
# /var/folders/tf/yjpqyrxd5c9g05p7rvlzpk0m0000gn/T/ipykernel_63320/1234462938.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ents_identical_by_lang[ents_identical_by_lang["pivot_lang"] == "ja"][
#       ents_identical pivot_lang  \
# 1003           False         ja
# 1004           False         ja
# 1007           False         ja
# 1012           False         ja
# 1013           False         ja
# 1014           False         ja
# 1019           False         ja
# 1027           False         ja
# 1028           False         ja
# 1052           False         ja
# 1053           False         ja
# 1055           False         ja
# 1060           False         ja
# 1065           False         ja
# 1071           False         ja
# 1075           False         ja
# 1076           False         ja
# 1079           False         ja
# 1080           False         ja
# 1081           False         ja
# 1084           False         ja
# 1103           False         ja
# 1104           False         ja
# 1105           False         ja
# 1106           False         ja
# 1109           False         ja
# 1115           False         ja
# 1124           False         ja
# 1129           False         ja
# 1135           False         ja
#
#                                                                                                                                                                  question  \
# 1003                                                                                                                                           Who commands the reserves?
# 1004                                                                                                                                   Who issued the Pragmatic Sanction?
# 1007                                                  What country's government, on which the US government was modeled, did not formally implement separation of powers?
# 1012                                                                                                       In what year did Francis, Duke of Anjou leave the Netherlands?
# 1013                                                                                                        The Kingdom of the Netherlands was formed by which countries?
# 1014                                                                                                         Which city in the Netherlands has the oldest stock exchange?
# 1019                                                                                                    Who had more power during times of war than the raadspensionaris?
# 1027                                                                                                                           What is an example of a Sassanid language?
# 1028                                                                                                          At what century's start did revivalist fall into disfavor?
# 1052                                                                                                                           When did Middle Persian start being u sed?
# 1053                                                                                                                            Each Brigade contains how many regiments?
# 1055                                                 What characteristic of Middle Iranian civilization is shown by the number of different languages and their speakers?
# 1060                                                                                                                   Where is the Information Management Group located?
# 1065                                                                                                           When did Canada gain independence from the United Kingdom?
# 1071                                                   In addition to forms from the ancient Middle East, what other place's forms had an effect on Islamic architecture?
# 1075                                                                                                                                Who advises the Chief of the Defence?
# 1076                                                                                               What area was the name Dari connected to by medieval Iranian thinkers?
# 1079                                                                                                             Where is the current focus of the Canadian Military set?
# 1080                                                                                                         Who has the responsibility to confirm Generals and Admirals?
# 1081  What is an example of a condition that must be met for the Internet Archive data to be considered acceptable for submission to patent offices in the US and Europe?
# 1084                                                                                                        The Dutch Republic was a republic of Europe during what time?
# 1103                                                                                                                      What century was the architect Le Corbusier in?
# 1104                                                                                      What other title does the Dean of Collge of Cardinals receive upon appointment?
# 1105                                                                                                                       How were the Canadian Forces upgraded in 2008?
# 1106                                                                                                             What has a color temperature around 2800 to 3000 Kelvin?
# 1109                                                                                                 What is one of the activities the CAF works on with other countries?
# 1115                                                                                                                 Which President attempted to pack the supreme court?
# 1124                                                                                                                                 Who receives the hishopric of Ostia?
# 1129                                                                                                            What are some other names the Dutch Republic is known by?
# 1135                                                                                            The Canadian Armed Forces were initially organized under what department?
#
#                                                                                                                                      backtranslation
# 1003                                                                                                              Who will command the Reserve Army?
# 1004                                                                                                                 Who issued practical sanctions?
# 1007                         Which government has served as a model for the U.S. government but never formally implemented the separation of powers?
# 1012                                                                                      What year did Franz, Duke of Anjou, leave the Netherlands?
# 1013                                                                                     Which country was the Kingdom of the Netherlands formed by?
# 1014                                                                                                 Which Dutch city has the oldest stock exchange?
# 1019                                                                                         Who held more power during the war than Lars Pensioner?
# 1027                                                                                                                         An example in Sasanian?
# 1028                                                                                        At the beginning of what century were revivalists hated?
# 1052                                                                                                        When did Medieval Persian come into use?
# 1053                                                                                                   How many regiments does each brigade contain?
# 1055                 What characteristics do the number of languages and the number of their speakers characterize the civilization of central Iran?
# 1060                                                                                                      Where is the information management group?
# 1065                                                                                          When did Canada become independent from Great Britain?
# 1071                                            In addition to ancient Middle Eastern forms, what other local forms influenced Islamic architecture?
# 1075                                                                                                           Who advises the Secretary of Defense?
# 1076                                                                          What realm did medieval Iranian thinkers associate the name Dali with?
# 1079                                                                                              What is the current focus of Canadian Forces sets?
# 1080                                                                                         Who is responsible for verifying generals and admirals?
# 1081  What are some examples of conditions that must be met for Internet Archive data to be considered fileable with US and European Patent Offices?
# 1084                                                                                                When was the Dutch Republic a European republic?
# 1103                                                                                          In what century was the architect Le Corbusier active?
# 1104                                                                           What other titles do Cardinal College deans receive upon appointment?
# 1105                                                                                             How was the Canadian Armed Forces upgraded in 2008?
# 1106                                                                                      What has a color temperature between 2800 and 3000 Kelvin?
# 1109                                                    Please tell us about one of the activities CAF is doing in cooperation with other countries.
# 1115                                                                                                Which president tried to fill the Supreme Court?
# 1124                                                                                                            Who receives the Hishopric of Ostia?
# 1129                                                                                                What other names is the Dutch Republic known by?
# 1135                                                                         Under what division was the Canadian Armed Forces originally organized?

# %%
df.groupby("pivot_lang").apply(
    lambda x: pd.Series(
        {
            "identical": (
                sum([
                    question_ents == backtranslation_ents
                    for (question_ents, backtranslation_ents)
                    in zip(
                        get_text_entities_for_series(x.question),
                        get_text_entities_for_series(x.backtranslation)
                    )
                ])
            )
        }
    )
)
# Out:
# Type of x: 0      The Dutch operated a slave trade from which lo...
# 1      What land is near the worms' first known locat...
# 2      How many days can the Daysimeter gather for an...
# 3                             Who commands the reserves?
# 4                     Who issued the Pragmatic Sanction?
#                              ...
# 995    When did usage of Middle Persian script fall off?
# 996    Where does the information stored on the Wayba...
# 997    Which courts decisions are binding across the ...
# 998    Who had granted Franklin Roosevelt sweeping au...
# 999    What made it possible to design architecture t...
# Name: question, Length: 1000, dtype: object
# Idx 0:	Elem: The Dutch operated a slave trade from which locations?	Type: <class 'str'>
# Type of x: 0      The Dutch operated a slave trade from which lo...
# 1      What land is near the first known location of ...
# 2      How many days can the Daysimeter collect for a...
# 3                             Who commands the reserves?
# 4                     Who issued the Pragmatic Sanction?
#                              ...
# 995    When did the use of the Middle Persian script ...
# 996    Where does the information stored in the Wayba...
# 997    What court decisions are binding on the entire...
# 998    Who had given Franklin Roosevelt absolute auth...
# 999    What made it possible to design architecture t...
# Name: backtranslation, Length: 1000, dtype: object
# Idx 0:	Elem: The Dutch operated a slave trade from which locations?	Type: <class 'str'>
# Type of x: 1000    The Dutch operated a slave trade from which lo...
# 1001    What land is near the worms' first known locat...
# 1002    How many days can the Daysimeter gather for an...
# 1003                           Who commands the reserves?
# 1004                   Who issued the Pragmatic Sanction?
#                               ...
# 1995    When did usage of Middle Persian script fall off?
# 1996    Where does the information stored on the Wayba...
# 1997    Which courts decisions are binding across the ...
# 1998    Who had granted Franklin Roosevelt sweeping au...
# 1999    What made it possible to design architecture t...
# Name: question, Length: 1000, dtype: object
# Idx 0:	Elem: The Dutch operated a slave trade from which locations?	Type: <class 'str'>
# Type of x: 1000                    Where did the Dutch trade slaves?
# 1001    What land is near where earthworms were first ...
# 1002    How many days can the Daysimeter collect for a...
# 1003                   Who will command the Reserve Army?
# 1004                      Who issued practical sanctions?
#                               ...
# 1995    When did the use of Middle Persian script decl...
# 1996    Where does the information stored on the Wayba...
# 1997    Which court decisions are binding across the U...
# 1998    Who gave Franklin Roosevelt full power during ...
# 1999    What made it possible to design architecture w...
# Name: backtranslation, Length: 1000, dtype: object
# Idx 0:	Elem: Where did the Dutch trade slaves?	Type: <class 'str'>
#             identical
# pivot_lang
# es                785
# ja                705

# %%
df.head()
# Out:
#                          id                  title  \
# 0  56dde2609a695914005b964b         Dutch_Republic
# 1  56de25ab4396321400ee260b              Symbiosis
# 2  56df9a3738dc4217001520bf               Lighting
# 3  56df065d3277331400b4d8c7  Canadian_Armed_Forces
# 4  56dddab666d3e219004dad30         Dutch_Republic
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  context  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Between 1590–1712 the Dutch also possessed one of the strongest and fastest navies in the world, allowing for their varied conquests including breaking the Portuguese sphere of influence on the Indian Ocean and in the Orient, as well as a lucrative slave trade from Africa and the Pacific.
# 1                                                                                                                                                                                                                                               One of the most spectacular examples of obligate mutualism is between the siboglinid tube worms and symbiotic bacteria that live at hydrothermal vents and cold seeps. The worm has no digestive tract and is wholly reliant on its internal symbionts for nutrition. The bacteria oxidize either hydrogen sulfide or methane, which the host supplies to them. These worms were discovered in the late 1980s at the hydrothermal vents near the Galapagos Islands and have since been found at deep-sea hydrothermal vents and cold seeps in all of the world's oceans.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                   The small, head-mounted device measures an individual's daily rest and activity patterns, as well as exposure to short-wavelength light that stimulates the circadian system. The device measures activity and light together at regular time intervals and electronically stores and logs its operating temperature. The Daysimeter can gather data for up to 30 days for analysis.
# 3  Approximately 26,000 citizen soldiers, sailors, and airmen and women, trained to the level of and interchangeable with their Regular Force counterparts, and posted to CAF operations or duties on a casual or ongoing basis, make up the Primary Reserve. This group is represented, though not commanded, at NDHQ by the Chief of Reserves and Cadets, who is usually a major general or rear admiral, and is divided into four components that are each operationally and administratively responsible to its corresponding environmental command in the Regular Force – the Naval Reserve (NAVRES), Land Force Reserve (LFR), and Air Reserve (AIRRES) – in addition to one force that does not fall under an environmental command, the Health Services Reserve under the Canadian Forces Health Services Group.
# 4                                                                                                                                                                                       Most of the Low Countries had come under the rule of the House of Burgundy and subsequently the House of Habsburg. In 1549 Holy Roman Emperor Charles V issued the Pragmatic Sanction, which further unified the Seventeen Provinces under his rule. Charles was succeeded by his son, King Philip II of Spain. In 1568 the Netherlands, led by William I of Orange, revolted against Philip II because of high taxes, persecution of Protestants by the government, and Philip's efforts to modernize and centralize the devolved-medieval government structures of the provinces. This was the start of the Eighty Years' War.
#
#                                                  question  \
# 0  The Dutch operated a slave trade from which locations?
# 1      What land is near the worms' first known location?
# 2   How many days can the Daysimeter gather for analysis?
# 3                              Who commands the reserves?
# 4                      Who issued the Pragmatic Sanction?
#
#                                                              answers  \
# 0        {'text': ['Africa and the Pacific'], 'answer_start': [266]}
# 1         {'text': ['the Galapagos Islands'], 'answer_start': [429]}
# 2                            {'text': ['30'], 'answer_start': [351]}
# 3  {'text': ['Chief of Reserves and Cadets'], 'answer_start': [315]}
# 4  {'text': ['Holy Roman Emperor Charles V'], 'answer_start': [123]}
#
#                                                                translation  \
# 0      ¿Los holandeses operaron un comercio de esclavos desde qué lugares?
# 1  ¿Qué tierra está cerca de la primera ubicación conocida de los gusanos?
# 2           ¿Cuántos días puede recolectar el Daysimeter para el análisis?
# 3                                            ¿Quién manda en las reservas?
# 4                                      ¿Quién dictó la Pragmática Sanción?
#
#                                             backtranslation source_lang  \
# 0    The Dutch operated a slave trade from which locations?       en-US
# 1  What land is near the first known location of the worms?       en-US
# 2    How many days can the Daysimeter collect for analysis?       en-US
# 3                                Who commands the reserves?       en-US
# 4                        Who issued the Pragmatic Sanction?       en-US
#
#   pivot_lang
# 0         es
# 1         es
# 2         es
# 3         es
# 4         es

# %%
df_small = df[["id", "question", "backtranslation", "pivot_lang"]]

# %%
df_small
# Out:
#                             id  \
# 0     56dde2609a695914005b964b
# 1     56de25ab4396321400ee260b
# 2     56df9a3738dc4217001520bf
# 3     56df065d3277331400b4d8c7
# 4     56dddab666d3e219004dad30
# ...                        ...
# 1995  56de0b40cffd8e1900b4b571
# 1996  56ddb46c9a695914005b958e
# 1997  56de40c0cffd8e1900b4b710
# 1998  56de485ccffd8e1900b4b789
# 1999  56e4c33039bdeb14003479bc
#
#                                                                                 question  \
# 0                                 The Dutch operated a slave trade from which locations?
# 1                                     What land is near the worms' first known location?
# 2                                  How many days can the Daysimeter gather for analysis?
# 3                                                             Who commands the reserves?
# 4                                                     Who issued the Pragmatic Sanction?
# ...                                                                                  ...
# 1995                                   When did usage of Middle Persian script fall off?
# 1996                 Where does the information stored on the Wayback Machine come from?
# 1997                 Which courts decisions are binding across the entire United States?
# 1998  Who had granted Franklin Roosevelt sweeping authority during the great depression?
# 1999         What made it possible to design architecture through new means and methods?
#
#                                                                backtranslation  \
# 0                       The Dutch operated a slave trade from which locations?
# 1                     What land is near the first known location of the worms?
# 2                       How many days can the Daysimeter collect for analysis?
# 3                                                   Who commands the reserves?
# 4                                           Who issued the Pragmatic Sanction?
# ...                                                                        ...
# 1995                        When did the use of Middle Persian script decline?
# 1996       Where does the information stored on the Wayback Machine come from?
# 1997               Which court decisions are binding across the United States?
# 1998       Who gave Franklin Roosevelt full power during the Great Depression?
# 1999  What made it possible to design architecture with new means and methods?
#
#      pivot_lang
# 0            es
# 1            es
# 2            es
# 3            es
# 4            es
# ...         ...
# 1995         ja
# 1996         ja
# 1997         ja
# 1998         ja
# 1999         ja
#
# [2000 rows x 4 columns]

# %%
df_pivot = df_small.pivot(index="id", columns=["pivot_lang"], values=["question", "backtranslation"])

# %%
df_pivot.head(60)
# Out:
#                                                                                                                                                                                      question  \
# pivot_lang                                                                                                                                                                                 es
# id
# 56ddb46c9a695914005b958e                                                                                                  Where does the information stored on the Wayback Machine come from?
# 56ddb46c9a695914005b958f                                                                                                                              Which company made the Wayback Machine?
# 56ddb46c9a695914005b9590                                                                                                                             Where is Internet Archive headquartered?
# 56ddb46c9a695914005b9591                                                                                                                           What individuals founded Internet Archive?
# 56ddb46c9a695914005b9592                                                                                           What is the term used by Internet Archive to describe the Wayback Machine?
# 56ddb53b66d3e219004daca3                                                                                                          What operating system is used on Wayback Machine's servers?
# 56ddb53b66d3e219004daca4                                                                                                                  When does Wayback Machine save a copy of a website?
# 56ddb53b66d3e219004daca5                                                                                                                     What is the ultimate aim of the Wayback Machine?
# 56ddb92966d3e219004daca9                                                                                                   What TV show served as inspiration for the Wayback Machine's name?
# 56ddb92966d3e219004dacaa                                                            Which characters on The Rocky and Bullwinkle Show used a device that allowed them to travel through time?
# 56ddb92966d3e219004dacab                                                                                                          What was the machine used by Mr. Peabody and Sherman named?
# 56ddbae166d3e219004dacaf                                                                                                 When was the program necessary to crawl and archive the web created?
# 56ddbae166d3e219004dacb0                                                                    What is a term used for programs that automatically visit websites and record the data they find?
# 56ddbae166d3e219004dacb1                                                                                               What rule do crawlers abide by when determining which sites to record?
# 56ddbae166d3e219004dacb2                                                                                         What site was created to mitigate issues with incomplete copies of websites?
# 56ddbb4b66d3e219004dacb7                                                                                                     What medium was originally used to keep Internet Archive's data?
# 56ddbb4b66d3e219004dacb8                                                                                                          Who were sometimes permitted to use the Archive's database?
# 56ddbb4b66d3e219004dacb9                                                                                                                       At what milestone was the archive made public?
# 56ddbb4b66d3e219004dacba                                                                                                   Where was the event launching the publicly-available archive held?
# 56ddbc0e66d3e219004dacbf                                                                                                                        What are the saved versions of a site called?
# 56ddbc0e66d3e219004dacc0                                                                      What is the minimum amount of time that elapses before most snapshots are released for viewing?
# 56ddbc0e66d3e219004dacc1                                                                                            What term characterizes the rate at which snapshots are made of websites?
# 56ddbc9766d3e219004dacc5                                                              When did it become a requirement for websites to appear on Open Directory for inclusion in the Archive?
# 56ddbc9766d3e219004dacc6                                        Who stated that sites not on Open Directory were still being saved but would not be released until the Archive was reindexed?
# 56ddbc9766d3e219004dacc7                                                                                          When did Kaplan make comments about the status of non-Open Directory sites?
# 56ddbd6d66d3e219004daccb                                                                                                      In 2009, what size did the data saved by Wayback Machine reach?
# 56ddbd6d66d3e219004daccc                                                                     As of 2003, what was the rate of increase in the amount of data recorded by the Wayback Machine?
# 56ddbd6d66d3e219004daccd                                                                                                              Where does Wayback Machine keep its information stored?
# 56ddbd6d66d3e219004dacce                                                                                                                                      Who makes PetaBox rack systems?
# 56ddc1d966d3e219004dacd3                                                                                                      When did Internet Archive chance its platform for data storage?
# 56ddc1d966d3e219004dacd4                                                                                                                   Which platform did Internet Archive adopt in 2009?
# 56ddc1d966d3e219004dacd5                                                                                                                        Where does Internet archive run a datacenter?
# 56ddc21866d3e219004dacd9                                                                                                     When was an upgrade of the Wayback Machine released for testing?
# 56ddc47666d3e219004dacdd                                                                                       When were details of the test version of the updated Wayback Machine released?
# 56ddc47666d3e219004dacde                                                                                      The older version of Wayback Machine did not have much new data past what year?
# 56ddc47666d3e219004dacdf                                                                                The newer version of the Wayback Machine included date up to and including what year?
# 56ddc4d99a695914005b95bc                                                                          What was the functionality called that gave users the ability to save a snapshot of a site?
# 56ddc4d99a695914005b95bd                                                                                                                                 When was Save a Page made available?
# 56ddc5e59a695914005b95c0                                                                                                                 What 2009 court battle involved the Wayback Machine?
# 56ddc5e59a695914005b95c1                                                                                      Which company thought that Wayback Machine data was important for its argument?
# 56ddc5e59a695914005b95c2                                                                                           What did Chordiant request that the court deactivate on Netbula's website?
# 56ddc68966d3e219004dace5                                                             Who did Netbula believe was the entity that should be responsible for the availability of its snapshots?
# 56ddc68966d3e219004dace6                                                                                                                          Which party did Internet Archive side with?
# 56ddc6e266d3e219004daceb                                                                                                             Which judge presided over the Netbula v. Chordiant case?
# 56ddc6e266d3e219004dacec                                                                                                        In what jurisdiction was the Netbula v. Chordiant case tried?
# 56ddc6e266d3e219004daced                                                                                                    Which party won its argument regarding Netbula's robots.txt file?
# 56ddc9d49a695914005b95cd                                                                                                                                  What does Telewizja Polska operate?
# 56ddc9d49a695914005b95ce                                                                                                                                         What is EchoStar's platform?
# 56ddc9d49a695914005b95cf                                                             Which judge denied Telewizja Polska's attempt to block the use of Internet Archive contents as evidence?
# 56ddc9d49a695914005b95d0                                                                                                                                 Which judge overturned Keys' ruling?
# 56ddca9d9a695914005b95d7                                                                                                      When are Internet Archive timestamps useful for patent offices?
# 56ddca9d9a695914005b95d8  What is an example of a condition that must be met for the Internet Archive data to be considered acceptable for submission to patent offices in the US and Europe?
# 56ddcf4166d3e219004dacf7                                                                                                       What kind of limitations exist in keeping copies of a website?
# 56ddcf4166d3e219004dacf8                                                                                    The omission of what element in screenshots can make them unreliable as evidence?
# 56ddcf4166d3e219004dacf9                                                                                                           What elements of webpages are not used by Wayback Machine?
# 56ddcf4166d3e219004dacfa                                                                                     What kind of sites contain information that the Wayback Machine does not record?
# 56ddd0509a695914005b95ec                                                                                        What kinds of laws could the Wayback Machine be viewed as breaking in Europe?
# 56ddd0509a695914005b95ed                                                    What would the Internet Archive have to do if requested by someone whose content is available on Wayback Machine?
# 56ddd0509a695914005b95ee                                                                                  In what part of the website are Wayback Machine's rules regarding removing content?
# 56ddd22366d3e219004dacff                                                  Web pages that contained content critical of what religous movement were taken off of the Internet Archive in 2002?
#
#                                                                                                                                                                                                \
# pivot_lang                                                                                                                                                                                 ja
# id
# 56ddb46c9a695914005b958e                                                                                                  Where does the information stored on the Wayback Machine come from?
# 56ddb46c9a695914005b958f                                                                                                                              Which company made the Wayback Machine?
# 56ddb46c9a695914005b9590                                                                                                                             Where is Internet Archive headquartered?
# 56ddb46c9a695914005b9591                                                                                                                           What individuals founded Internet Archive?
# 56ddb46c9a695914005b9592                                                                                           What is the term used by Internet Archive to describe the Wayback Machine?
# 56ddb53b66d3e219004daca3                                                                                                          What operating system is used on Wayback Machine's servers?
# 56ddb53b66d3e219004daca4                                                                                                                  When does Wayback Machine save a copy of a website?
# 56ddb53b66d3e219004daca5                                                                                                                     What is the ultimate aim of the Wayback Machine?
# 56ddb92966d3e219004daca9                                                                                                   What TV show served as inspiration for the Wayback Machine's name?
# 56ddb92966d3e219004dacaa                                                            Which characters on The Rocky and Bullwinkle Show used a device that allowed them to travel through time?
# 56ddb92966d3e219004dacab                                                                                                          What was the machine used by Mr. Peabody and Sherman named?
# 56ddbae166d3e219004dacaf                                                                                                 When was the program necessary to crawl and archive the web created?
# 56ddbae166d3e219004dacb0                                                                    What is a term used for programs that automatically visit websites and record the data they find?
# 56ddbae166d3e219004dacb1                                                                                               What rule do crawlers abide by when determining which sites to record?
# 56ddbae166d3e219004dacb2                                                                                         What site was created to mitigate issues with incomplete copies of websites?
# 56ddbb4b66d3e219004dacb7                                                                                                     What medium was originally used to keep Internet Archive's data?
# 56ddbb4b66d3e219004dacb8                                                                                                          Who were sometimes permitted to use the Archive's database?
# 56ddbb4b66d3e219004dacb9                                                                                                                       At what milestone was the archive made public?
# 56ddbb4b66d3e219004dacba                                                                                                   Where was the event launching the publicly-available archive held?
# 56ddbc0e66d3e219004dacbf                                                                                                                        What are the saved versions of a site called?
# 56ddbc0e66d3e219004dacc0                                                                      What is the minimum amount of time that elapses before most snapshots are released for viewing?
# 56ddbc0e66d3e219004dacc1                                                                                            What term characterizes the rate at which snapshots are made of websites?
# 56ddbc9766d3e219004dacc5                                                              When did it become a requirement for websites to appear on Open Directory for inclusion in the Archive?
# 56ddbc9766d3e219004dacc6                                        Who stated that sites not on Open Directory were still being saved but would not be released until the Archive was reindexed?
# 56ddbc9766d3e219004dacc7                                                                                          When did Kaplan make comments about the status of non-Open Directory sites?
# 56ddbd6d66d3e219004daccb                                                                                                      In 2009, what size did the data saved by Wayback Machine reach?
# 56ddbd6d66d3e219004daccc                                                                     As of 2003, what was the rate of increase in the amount of data recorded by the Wayback Machine?
# 56ddbd6d66d3e219004daccd                                                                                                              Where does Wayback Machine keep its information stored?
# 56ddbd6d66d3e219004dacce                                                                                                                                      Who makes PetaBox rack systems?
# 56ddc1d966d3e219004dacd3                                                                                                      When did Internet Archive chance its platform for data storage?
# 56ddc1d966d3e219004dacd4                                                                                                                   Which platform did Internet Archive adopt in 2009?
# 56ddc1d966d3e219004dacd5                                                                                                                        Where does Internet archive run a datacenter?
# 56ddc21866d3e219004dacd9                                                                                                     When was an upgrade of the Wayback Machine released for testing?
# 56ddc47666d3e219004dacdd                                                                                       When were details of the test version of the updated Wayback Machine released?
# 56ddc47666d3e219004dacde                                                                                      The older version of Wayback Machine did not have much new data past what year?
# 56ddc47666d3e219004dacdf                                                                                The newer version of the Wayback Machine included date up to and including what year?
# 56ddc4d99a695914005b95bc                                                                          What was the functionality called that gave users the ability to save a snapshot of a site?
# 56ddc4d99a695914005b95bd                                                                                                                                 When was Save a Page made available?
# 56ddc5e59a695914005b95c0                                                                                                                 What 2009 court battle involved the Wayback Machine?
# 56ddc5e59a695914005b95c1                                                                                      Which company thought that Wayback Machine data was important for its argument?
# 56ddc5e59a695914005b95c2                                                                                           What did Chordiant request that the court deactivate on Netbula's website?
# 56ddc68966d3e219004dace5                                                             Who did Netbula believe was the entity that should be responsible for the availability of its snapshots?
# 56ddc68966d3e219004dace6                                                                                                                          Which party did Internet Archive side with?
# 56ddc6e266d3e219004daceb                                                                                                             Which judge presided over the Netbula v. Chordiant case?
# 56ddc6e266d3e219004dacec                                                                                                        In what jurisdiction was the Netbula v. Chordiant case tried?
# 56ddc6e266d3e219004daced                                                                                                    Which party won its argument regarding Netbula's robots.txt file?
# 56ddc9d49a695914005b95cd                                                                                                                                  What does Telewizja Polska operate?
# 56ddc9d49a695914005b95ce                                                                                                                                         What is EchoStar's platform?
# 56ddc9d49a695914005b95cf                                                             Which judge denied Telewizja Polska's attempt to block the use of Internet Archive contents as evidence?
# 56ddc9d49a695914005b95d0                                                                                                                                 Which judge overturned Keys' ruling?
# 56ddca9d9a695914005b95d7                                                                                                      When are Internet Archive timestamps useful for patent offices?
# 56ddca9d9a695914005b95d8  What is an example of a condition that must be met for the Internet Archive data to be considered acceptable for submission to patent offices in the US and Europe?
# 56ddcf4166d3e219004dacf7                                                                                                       What kind of limitations exist in keeping copies of a website?
# 56ddcf4166d3e219004dacf8                                                                                    The omission of what element in screenshots can make them unreliable as evidence?
# 56ddcf4166d3e219004dacf9                                                                                                           What elements of webpages are not used by Wayback Machine?
# 56ddcf4166d3e219004dacfa                                                                                     What kind of sites contain information that the Wayback Machine does not record?
# 56ddd0509a695914005b95ec                                                                                        What kinds of laws could the Wayback Machine be viewed as breaking in Europe?
# 56ddd0509a695914005b95ed                                                    What would the Internet Archive have to do if requested by someone whose content is available on Wayback Machine?
# 56ddd0509a695914005b95ee                                                                                  In what part of the website are Wayback Machine's rules regarding removing content?
# 56ddd22366d3e219004dacff                                                  Web pages that contained content critical of what religous movement were taken off of the Internet Archive in 2002?
#
#                                                                                                                                                                      backtranslation  \
# pivot_lang                                                                                                                                                                        es
# id
# 56ddb46c9a695914005b958e                                                                                         Where does the information stored in the Wayback Machine come from?
# 56ddb46c9a695914005b958f                                                                                                                      What company made the Wayback Machine?
# 56ddb46c9a695914005b9590                                                                                                                        Where is the Internet Archive based?
# 56ddb46c9a695914005b9591                                                                                                                   What people founded the Internet Archive?
# 56ddb46c9a695914005b9592                                                                              What is the term used by the Internet Archive to describe the Wayback Machine?
# 56ddb53b66d3e219004daca3                                                                                               What operating system is used on the Wayback Machine servers?
# 56ddb53b66d3e219004daca4                                                                                                     When does the Wayback Machine save a copy of a website?
# 56ddb53b66d3e219004daca5                                                                                                           What is the ultimate goal of the Wayback Machine?
# 56ddb92966d3e219004daca9                                                                                              What television show inspired the name of the Wayback Machine?
# 56ddb92966d3e219004dacaa                                                   Which characters on The Rocky and Bullwinkle Show used a device that allowed them to travel through time?
# 56ddb92966d3e219004dacab                                                                                           What was the name of the machine used by Mr. Peabody and Sherman?
# 56ddbae166d3e219004dacaf                                                                                           When was the program needed to crawl and archive the web created?
# 56ddbae166d3e219004dacb0                                                             What term is used for programs that automatically visit websites and record the data they find?
# 56ddbae166d3e219004dacb1                                                                                      What rule do crawlers follow when determining which sites to register?
# 56ddbae166d3e219004dacb2                                                                              What site was created to mitigate problems with incomplete copies of websites?
# 56ddbb4b66d3e219004dacb7                                                                                          What medium was originally used to save the Internet Archive data?
# 56ddbb4b66d3e219004dacb8                                                                                                    Who was sometimes allowed to use the Archive's database?
# 56ddbb4b66d3e219004dacb9                                                                                                                 At what milestone was the file made public?
# 56ddbb4b66d3e219004dacba                                                                                                    Where was the publicly available file launch event held?
# 56ddbc0e66d3e219004dacbf                                                                                                                   What are saved versions of a site called?
# 56ddbc0e66d3e219004dacc0                                                            What is the minimum amount of time that elapses before most snapshots are published for viewing?
# 56ddbc0e66d3e219004dacc1                                                                                 What term characterizes the speed at which snapshots of websites are taken?
# 56ddbc9766d3e219004dacc5                                                 When did it become a requirement for websites to appear in the Open Directory for inclusion in the Archive?
# 56ddbc9766d3e219004dacc6                             Who said that sites not in the Open Directory were still being saved but wouldn't be published until the Archive was reindexed?
# 56ddbc9766d3e219004dacc7                                                                                          When did Kaplan comment on the status of non-Open Directory sites?
# 56ddbd6d66d3e219004daccb                                                                                                 In 2009, how big was the data saved by the Wayback Machine?
# 56ddbd6d66d3e219004daccc                                                      Starting in 2003, what was the rate of increase in the amount of data recorded by the Wayback Machine?
# 56ddbd6d66d3e219004daccd                                                                                                      Where does the Wayback Machine store your information?
# 56ddbd6d66d3e219004dacce                                                                                                                         Who makes PetaBox shelving systems?
# 56ddc1d966d3e219004dacd3                                                                                        When did the Internet Archive put its data storage platform at risk?
# 56ddc1d966d3e219004dacd4                                                                                                       What platform did the Internet Archive adopt in 2009?
# 56ddc1d966d3e219004dacd5                                                                                                              Where does Internet Archive run a data center?
# 56ddc21866d3e219004dacd9                                                                                                     When was a Wayback Machine update released for testing?
# 56ddc47666d3e219004dacdd                                                                                               When were the updated Wayback Machine trial details released?
# 56ddc47666d3e219004dacde                                                                           The old version of the Wayback Machine didn't have much new data after what year?
# 56ddc47666d3e219004dacdf                                                              Does the newest version of the Wayback Machine include the date up to and including what year?
# 56ddc4d99a695914005b95bc                                                            What was the name of the functionality that gave users the ability to save a snapshot of a site?
# 56ddc4d99a695914005b95bd                                                                                                                             When was Save a Page available?
# 56ddc5e59a695914005b95c0                                                                                                       Which 2009 court battle involved the Wayback Machine?
# 56ddc5e59a695914005b95c1                                                                             Which company thought the Wayback Machine data was important to their argument?
# 56ddc5e59a695914005b95c2                                                                                   What did Chordiant request that the court disable on the Netbula website?
# 56ddc68966d3e219004dace5                                                      Who did Netbula think was the entity that should be responsible for the availability of its snapshots?
# 56ddc68966d3e219004dace6                                                                                                                     What party did Internet Archive put on?
# 56ddc6e266d3e219004daceb                                                                                                         Which judge presided over the Netbula v. Chordiant?
# 56ddc6e266d3e219004dacec                                                                                                          In what jurisdiction was the Netbula v. Chordiant?
# 56ddc6e266d3e219004daced                                                                                               Which part won your argument about Netbula's robots.txt file?
# 56ddc9d49a695914005b95cd                                                                                                                         What does Telewizja Polska operate?
# 56ddc9d49a695914005b95ce                                                                                                                              What is the EchoStar platform?
# 56ddc9d49a695914005b95cf                                                     Which judge denied Telewizja Polska's attempt to block the use of Internet Archive content as evidence?
# 56ddc9d49a695914005b95d0                                                                                                                        Which judge overturned Keys' ruling?
# 56ddca9d9a695914005b95d7                                                                                              When are Internet Archive timestamps useful to patent offices?
# 56ddca9d9a695914005b95d8  What is an example of a condition that must be met for Internet Archive data to be considered acceptable for submission to US and European patent offices?
# 56ddcf4166d3e219004dacf7                                                                                         What kind of limitations are there for keeping copies of a website?
# 56ddcf4166d3e219004dacf8                                                                       The omission of what element in the screenshots can make them unreliable as evidence?
# 56ddcf4166d3e219004dacf9                                                                                                What elements of web pages does the Wayback Machine not use?
# 56ddcf4166d3e219004dacfa                                                                           What types of sites contain information that the Wayback Machine does not record?
# 56ddd0509a695914005b95ec                                                                               What kind of laws could the Wayback Machine be considered breaking in Europe?
# 56ddd0509a695914005b95ed                                        What would the Internet Archive have to do if someone whose content is available on the Wayback Machine requests it?
# 56ddd0509a695914005b95ee                                                                            Where on the website are the Wayback Machine rules regarding removal of content?
# 56ddd22366d3e219004dacff                                           Web pages containing content critical of which religious movement were removed from the Internet Archive in 2002?
#
#
# pivot_lang                                                                                                                                                            ja
# id
# 56ddb46c9a695914005b958e                                                                             Where does the information stored on the Wayback Machine come from?
# 56ddb46c9a695914005b958f                                                                                                          What company made the Wayback Machine?
# 56ddb46c9a695914005b9590                                                                                                     Where is the Internet Archive headquarters?
# 56ddb46c9a695914005b9591                                                                                                               Who founded the Internet Archive?
# 56ddb46c9a695914005b9592                                                                        What term does the Internet Archive use to describe the Wayback Machine?
# 56ddb53b66d3e219004daca3                                                                                 What operating system is used on the Wayback Machine's servers?
# 56ddb53b66d3e219004daca4                                                                                      When does the Wayback Machine store a copy of the website?
# 56ddb53b66d3e219004daca5                                                                                            What is the ultimate purpose of the Wayback Machine?
# 56ddb92966d3e219004daca9                                                                                                 What TV show inspired the name Wayback Machine?
# 56ddb92966d3e219004dacaa                                        Which character on The Rocky and Bullwinkle Show used a device that allowed them to travel through time?
# 56ddb92966d3e219004dacab                                                                           What was the name of the machine used by Mr. Peabody and Mr. Sherman?
# 56ddbae166d3e219004dacaf                                                                                      When was the program created to crawl and archive the web?
# 56ddbae166d3e219004dacb0                                                What is the term for a program that automatically visits websites and records the data it finds?
# 56ddbae166d3e219004dacb1                                                                         What rules does the crawler follow when deciding which sites to record?
# 56ddbae166d3e219004dacb2                                                                   What site was created to alleviate the problem of incomplete web site copies?
# 56ddbb4b66d3e219004dacb7                                                                                  What media was originally used to store Internet Archive data?
# 56ddbb4b66d3e219004dacb8                                                                                     Who was occasionally allowed to use the archive's database?
# 56ddbb4b66d3e219004dacb9                                                                                                    At what milestone was the archive published?
# 56ddbb4b66d3e219004dacba                                                                                          Where was the event to reveal the public archive held?
# 56ddbc0e66d3e219004dacbf                                                                                                       What are saved versions of a site called?
# 56ddbc0e66d3e219004dacc0                                                       What is the minimum amount of time it takes for most snapshots to be exposed and visible?
# 56ddbc0e66d3e219004dacc1                                                                                     What is the term for how often a website snapshot is taken?
# 56ddbc9766d3e219004dacc5                                                  When was it a requirement that a website appear in Open Directory for inclusion in an archive?
# 56ddbc9766d3e219004dacc6                            Who said sites that aren't in Open Directory are still stored, but won't be released until the archive is reindexed?
# 56ddbc9766d3e219004dacc7                                                                              When did Kaplan comment on the status of non-Open Directory sites?
# 56ddbd6d66d3e219004daccb                                                                             What size did the data stored by the Wayback Machine reach in 2009?
# 56ddbd6d66d3e219004daccc                                                      What was the growth rate of the amount of data recorded by the Wayback Machine as of 2003?
# 56ddbd6d66d3e219004daccd                                                                                                    Where is Wayback Machine information stored?
# 56ddbd6d66d3e219004dacce                                                                                                              Who makes the PetaBox rack system?
# 56ddc1d966d3e219004dacd3                                                                     When did the Internet Archive make its platform available for data storage?
# 56ddc1d966d3e219004dacd4                                                                                          Which platform did the Internet Archive adopt in 2009?
# 56ddc1d966d3e219004dacd5                                                                                           Where does Internet Archive operate its data centers?
# 56ddc21866d3e219004dacd9                                                                                      When was the Wayback Machine upgrade released for testing?
# 56ddc47666d3e219004dacdd                                                                     When were the details of the updated Wayback Machine test version released?
# 56ddc47666d3e219004dacde                                                         How many years later did the old version of the Wayback Machine not have much new data?
# 56ddc47666d3e219004dacdf                                                                                  What year was the new version of the Wayback Machine dated to?
# 56ddc4d99a695914005b95bc                                                                  What was the feature that allowed users to save a snapshot of the site called?
# 56ddc4d99a695914005b95bd                                                                                                                   When was Save Page available?
# 56ddc5e59a695914005b95c0                                                                                               A legal battle involving Wayback Machine in 2009?
# 56ddc5e59a695914005b95c1                                                                      Which company thought the Wayback Machine data was important to its claim?
# 56ddc5e59a695914005b95c2                                                                          What prompted Chordiant to ask the court to disable Netbula's website?
# 56ddc68966d3e219004dace5                                                                   Who did Netbula believe was the entity responsible for snapshot availability?
# 56ddc68966d3e219004dace6                                                                                       Which political party did the Internet Archive side with?
# 56ddc6e266d3e219004daceb                                                                                                 Which judge presided over Netbula v. Chordiant?
# 56ddc6e266d3e219004dacec                                                                                           In which jurisdiction was Netbula v. Chordiant heard?
# 56ddc6e266d3e219004daced                                                                                      Which party won the debate over Netbula's robots.txt file?
# 56ddc9d49a695914005b95cd                                                                                                             What does Telewizja Polska operate?
# 56ddc9d49a695914005b95ce                                                                                                                  What is the EchoStar platform?
# 56ddc9d49a695914005b95cf                                     Which judge denied Telewizja Polska's attempts to stop him from using Internet Archive content as evidence?
# 56ddc9d49a695914005b95d0                                                                                                         Which judge overturned Keyes' decision?
# 56ddca9d9a695914005b95d7                                                                                 When are Internet Archive timestamps useful for patent offices?
# 56ddca9d9a695914005b95d8  What are some examples of conditions that must be met for Internet Archive data to be considered fileable with US and European Patent Offices?
# 56ddcf4166d3e219004dacf7                                                                                     What are the restrictions on keeping a copy of the website?
# 56ddcf4166d3e219004dacf8                                                                What elements of screenshots can be omitted to make them unreliable as evidence?
# 56ddcf4166d3e219004dacf9                                                                                    Which web page elements are not used by the Wayback Machine?
# 56ddcf4166d3e219004dacfa                                                                        What sites contain information that the Wayback Machine does not record?
# 56ddd0509a695914005b95ec                                                                             What laws can the Wayback Machine be considered breaking in Europe?
# 56ddd0509a695914005b95ed                                    What must the Internet Archive do if requested by someone who can obtain the content on the Wayback Machine?
# 56ddd0509a695914005b95ee                                                                  What part of the website has the Wayback Machine's rules for removing content?
# 56ddd22366d3e219004dacff                             What web pages contain content critical of religious movements that were removed from the Internet Archive in 2002?

# %% [markdown]
# ## How many sentences that began with "who", "what", "when", "where", "why", and "how" were reworded?

# %%
def question_starts_with_word(text: str, word: str) -> bool:
    return text.lower().startswith(word)

# %%
def question_starts_with_certain_words(text: str, word_list: List[str]) -> bool:
    return any([
        question_starts_with_word(text=text, word=word)
        for word in word_list
    ])

# %%
INTERROGATIVE_WORD_LIST = ["who", "what", "when", "where", "why", "how"]

# %%
df["question_starts_with_interrogative_words"] = [
    question_starts_with_certain_words(
        text=text, word_list=INTERROGATIVE_WORD_LIST
    )
    for text in df["question"]
]

df["backtranslation_starts_with_interrogative_words"] = [
    question_starts_with_certain_words(
        text=text, word_list=INTERROGATIVE_WORD_LIST
    )
    for text in df["backtranslation"]
]

# %%
is_identical_bool_list = [
    question == backtranslation
    for (question, backtranslation)
    in zip(df["question"], df["backtranslation"])
]

# %%
df["question_backtranslation_identical_bool"] = is_identical_bool_list

# %%
df_interrogation = df[
    [
        "id", "question", "backtranslation", "pivot_lang",
        "question_starts_with_interrogative_words",
        "backtranslation_starts_with_interrogative_words",
        "question_backtranslation_identical_bool"
    ]
]

# %%
df_interrogation.head()
# Out:
#                          id  \
# 0  56dde2609a695914005b964b
# 1  56de25ab4396321400ee260b
# 2  56df9a3738dc4217001520bf
# 3  56df065d3277331400b4d8c7
# 4  56dddab666d3e219004dad30
#
#                                                  question  \
# 0  The Dutch operated a slave trade from which locations?
# 1      What land is near the worms' first known location?
# 2   How many days can the Daysimeter gather for analysis?
# 3                              Who commands the reserves?
# 4                      Who issued the Pragmatic Sanction?
#
#                                             backtranslation pivot_lang  \
# 0    The Dutch operated a slave trade from which locations?         es
# 1  What land is near the first known location of the worms?         es
# 2    How many days can the Daysimeter collect for analysis?         es
# 3                                Who commands the reserves?         es
# 4                        Who issued the Pragmatic Sanction?         es
#
#    question_starts_with_interrogative_words  \
# 0                                     False
# 1                                      True
# 2                                      True
# 3                                      True
# 4                                      True
#
#    backtranslation_starts_with_interrogative_words  \
# 0                                            False
# 1                                             True
# 2                                             True
# 3                                             True
# 4                                             True
#
#    question_backtranslation_identical_bool
# 0                                     True
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                     True

# %%
# how many English seed phrases start with interrogative word.
df_interrogation["question_starts_with_interrogative_words"].value_counts()
# Out:
# True     1526
# False     474
# Name: question_starts_with_interrogative_words, dtype: int64

# %% [markdown]
# #### How many phrases that initially start with an interrogative word are then reworded?

# %%
"foo".startswith("fa")
# Out:
# False
